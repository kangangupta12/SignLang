# %% [markdown]
# # Notebook 2: Train Small Demo
#
# Quick experiment using a subset for sanity checks.

# %%
# %load_ext tensorboard
import os
# !python -m src.train --dataset_dir dataset/videos --epochs 2 --batch_size 2 --seq_len 16 --checkpoint_dir models/demo
